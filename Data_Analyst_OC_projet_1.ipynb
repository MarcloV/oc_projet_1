# %% [markdown]
# # 24h dans la peau d'un Data Analyst

# %% [markdown]
# Mission n°1
#
# Repérez le graphique présentant une anomalie. Que faites-vous ? Rédigez un bref mail de compte rendu à votre chef, en lui expliquant que pour le moment, vous ne savez pas d'où vient le problème, mais donnant quelques suppositions, et en précisant les personnes que vous avez contactées pour le régler.

# %%
# !pip install --user opencv-python
#!pip install --user imageio
#!pip list --format=columns
# Out:
# ...
# tensorflow 1.3.0 requires tensorflow-tensorboard<0.2.0,>=0.1.0, which is not installed.

# %%
# imports for image processing
import cv2
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from skimage import io as skyio
from mpl_toolkits.mplot3d import Axes3D

# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.

# %%
# Extract slots from credentials
# Bucket
cgsBucket = cgsCreds['BUCKET']
# Filename
cgsImage = cgsCreds['FILE']
# Verify current values
print(cgsBucket, cgsImage)
# Out:
# dataanalystoc-donotdelete-pr-we7lomv4sldueb 13.png

# %%
# Method to read image from cos into numpy.ndarray
def cgsReadImage(client, bucket, file):
    # Download file from COS into a 'ibm_botocore.response.StreamingBody' object
    isr = client.get_object(Bucket=bucket, Key=file)
    # Extract the jpeg image data from the 'Body' slot into a byte array
    jpg = isr['Body']
    print(type(jpg))
    # needed by skyio.imread
    if not hasattr(jpg, "__iter__"): jpg.__iter__ = types.MethodType( __iter__, jpg )
    # Convert the jpeg image data into a numpy.ndarray of size rRows*cCols*nColorChannels
    img = skyio.imread(jpg)
    # Print some stats
    print("cgsReadImage: \n\tBucket=%s \n\tFile=%s \n\tArraySize=%d %s Type=%s\n" % (bucket, file, img.size, img.shape, img.dtype))
    return(img)

# %%
# Read image from COS
jpg = cgsReadImage(cgsClient, cgsBucket, cgsImage)
# Out:
# <class 'ibm_botocore.response.StreamingBody'>
# cgsReadImage:
# 	Bucket=dataanalystoc-donotdelete-pr-we7lomv4sldueb
# 	File=13.png
# 	ArraySize=1306368 (504, 648, 4) Type=uint8

# %%
cgsDefPlotSize=[12,12]
mpl.rcParams['figure.figsize'] = cgsDefPlotSize

# %% [markdown]
# ### Graphique présentant une anomalie

# %%
# plot image
plt.imshow(jpg)
plt.show()

# %% [markdown]
# ## Mail de compte rendu

# %% [markdown]
# Bonjour Monsieur,
#
# je viens de repérer une anomalie dans les achats du 3 derniers mois. Il y n'y a eu aucune achat des produits high-tech. Je suis en train de rédiger un mail au secteur concerné pour leur communiquer ce fait. L’absence d'achats des produits high-tech a entrainé une baisse de la chiffre d'affaires donc il est très important comprendre l’origine du problème.
#
# Je vous tiens au courant.
#
# Très cordialement,
#
# Marcelo

# %% [markdown]
# ## Mission n°2
#
# Effectuez une courte présentation avec un logiciel adapté, en ne sélectionnant que les 5 graphiques les plus pertinents parmi ceux que votre script a générés. Attention à votre choix, car vos 5 graphiques devront impérativement rendre compte de toutes les dimensions suivantes :
#
# * proportion des ventes par catégorie de produit
# * montant des achats des clients (montant du panier)
# * évolution du chiffre d'affaires
# * évolution du nombre d'achats des clients
# * évolution du ratio (nombre de visites)/(nombre d'achats des clients) au cours du temps
# * évolution du nombre de visites sur le site web au cours du temps
# * temps passé par les visiteurs sur le site web (pour toutes les sessions)
# * évolution de la variabilité du temps passé par les visiteurs sur le site web (pour les sessions ayant abouti à un achat)
#
# Pensez-vous que le chiffre d'affaires ré-augmentera le mois prochain ? Justifiez votre réponse uniquement à l'aide d'un des 5 graphiques choisis.
#
# Vous avez le droit également d'interpréter cette baisse en vous basant sur un graphique que vous avez choisi de ne pas inclure parmi les 5.

# %% [markdown]
# ## Graphique présentant la proportion des ventes par catégorie de produit et l'évolution du chiffre d'affaires

# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.

# %%
# Extract slots from credentials
# Bucket
cgsBucket_5 = cgsCreds_5['BUCKET']
# Filename
cgsImage_5 = cgsCreds_5['FILE']
# Verify current values
print(cgsBucket_5, cgsImage_5)
# Out:
# dataanalystoc-donotdelete-pr-we7lomv4sldueb 12.png

# %%
# Method to read image from cos into numpy.ndarray
def cgsReadImage(client, bucket, file):
    # Download file from COS into a 'ibm_botocore.response.StreamingBody' object
    isr_5 = client.get_object(Bucket=bucket, Key=file)
    # Extract the jpeg image data from the 'Body' slot into a byte array
    jpg_5 = isr_5['Body']
    print(type(jpg_5))
    # needed by skyio.imread
    if not hasattr(jpg_5, "__iter__"): jpg_5.__iter__ = types.MethodType( __iter__, jpg_5 )
    # Convert the jpeg image data into a numpy.ndarray of size rRows*cCols*nColorChannels
    img = skyio.imread(jpg_5)
    # Print some stats
    print("cgsReadImage: \n\tBucket=%s \n\tFile=%s \n\tArraySize=%d %s Type=%s\n" % (bucket, file, img.size, img.shape, img.dtype))
    return(img)

# %%
# Read image from COS
jpg_5 = cgsReadImage(cgsClient_5, cgsBucket_5, cgsImage_5)
# Out:
# <class 'ibm_botocore.response.StreamingBody'>
# cgsReadImage:
# 	Bucket=dataanalystoc-donotdelete-pr-we7lomv4sldueb
# 	File=12.png
# 	ArraySize=1306368 (504, 648, 4) Type=uint8

# %%
cgsDefPlotSize_5=[12,12]
mpl.rcParams['figure.figsize'] = cgsDefPlotSize_5

# %%
# plot image
plt.imshow(jpg_5)
plt.show()

# %% [markdown]
# ## Graphique présentant le montant des achats des clients (montant du panier) et temps passé par les visiteurs sur le site web (pour toutes les sessions)

# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.

# %%
# Extract slots from credentials
# Bucket
cgsBucket_1 = cgsCreds_1['BUCKET']
# Filename
cgsImage_1 = cgsCreds_1['FILE']
# Verify current values
print(cgsBucket_1, cgsImage_1)
# Out:
# dataanalystoc-donotdelete-pr-we7lomv4sldueb 5.png

# %%
# Method to read image from cos into numpy.ndarray
def cgsReadImage(client, bucket, file):
    # Download file from COS into a 'ibm_botocore.response.StreamingBody' object
    isr_1 = client.get_object(Bucket=bucket, Key=file)
    # Extract the jpeg image data from the 'Body' slot into a byte array
    jpg_1 = isr_1['Body']
    print(type(jpg_1))
    # needed by skyio.imread
    if not hasattr(jpg_1, "__iter__"): jpg_1.__iter__ = types.MethodType( __iter__, jpg_1 )
    # Convert the jpeg image data into a numpy.ndarray of size rRows*cCols*nColorChannels
    img = skyio.imread(jpg_1)
    # Print some stats
    print("cgsReadImage: \n\tBucket=%s \n\tFile=%s \n\tArraySize=%d %s Type=%s\n" % (bucket, file, img.size, img.shape, img.dtype))
    return(img)

# %%
# Read image from COS
jpg_1 = cgsReadImage(cgsClient_1, cgsBucket_1, cgsImage_1)
# Out:
# <class 'ibm_botocore.response.StreamingBody'>
# cgsReadImage:
# 	Bucket=dataanalystoc-donotdelete-pr-we7lomv4sldueb
# 	File=5.png
# 	ArraySize=1306368 (504, 648, 4) Type=uint8

# %%
cgsDefPlotSize_1=[12,12]
mpl.rcParams['figure.figsize'] = cgsDefPlotSize_1

# %%
# plot image
plt.imshow(jpg_1)
plt.show()

# %% [markdown]
# ## Graphique présentant l'évolution du ratio (nombre de visites)/(nombre d'achats des clients) au cours du temps et l'évolution du nombre de visites sur le site web au cours du temps

# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.

# %%
# Extract slots from credentials
# Bucket
cgsBucket_2 = cgsCreds_2['BUCKET']
# Filename
cgsImage_2 = cgsCreds_2['FILE']
# Verify current values
print(cgsBucket_2, cgsImage_2)
# Out:
# dataanalystoc-donotdelete-pr-we7lomv4sldueb 2.png

# %%
# Method to read image from cos into numpy.ndarray
def cgsReadImage(client, bucket, file):
    # Download file from COS into a 'ibm_botocore.response.StreamingBody' object
    isr_2 = client.get_object(Bucket=bucket, Key=file)
    # Extract the jpeg image data from the 'Body' slot into a byte array
    jpg_2 = isr_2['Body']
    print(type(jpg_2))
    # needed by skyio.imread
    if not hasattr(jpg_2, "__iter__"): jpg_2.__iter__ = types.MethodType( __iter__, jpg_2 )
    # Convert the jpeg image data into a numpy.ndarray of size rRows*cCols*nColorChannels
    img = skyio.imread(jpg_2)
    # Print some stats
    print("cgsReadImage: \n\tBucket=%s \n\tFile=%s \n\tArraySize=%d %s Type=%s\n" % (bucket, file, img.size, img.shape, img.dtype))
    return(img)

# %%
# Read image from COS
jpg_2 = cgsReadImage(cgsClient_2, cgsBucket_2, cgsImage_2)
# Out:
# <class 'ibm_botocore.response.StreamingBody'>
# cgsReadImage:
# 	Bucket=dataanalystoc-donotdelete-pr-we7lomv4sldueb
# 	File=2.png
# 	ArraySize=1306368 (504, 648, 4) Type=uint8

# %%
cgsDefPlotSize_2=[12,12]
mpl.rcParams['figure.figsize'] = cgsDefPlotSize_2

# %%
# plot image
plt.imshow(jpg_2)
plt.show()

# %% [markdown]
# ## Graphique présentant l'évolution du nombre d'achats des clients

# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.

# %%
# Extract slots from credentials
# Bucket
cgsBucket_3 = cgsCreds_3['BUCKET']
# Filename
cgsImage_3 = cgsCreds_3['FILE']
# Verify current values
print(cgsBucket_3, cgsImage_3)
# Out:
# dataanalystoc-donotdelete-pr-we7lomv4sldueb 1.png

# %%
# Method to read image from cos into numpy.ndarray
def cgsReadImage(client, bucket, file):
    # Download file from COS into a 'ibm_botocore.response.StreamingBody' object
    isr_3 = client.get_object(Bucket=bucket, Key=file)
    # Extract the jpeg image data from the 'Body' slot into a byte array
    jpg_3 = isr_3['Body']
    print(type(jpg_3))
    # needed by skyio.imread
    if not hasattr(jpg_3, "__iter__"): jpg_3.__iter__ = types.MethodType( __iter__, jpg_3 )
    # Convert the jpeg image data into a numpy.ndarray of size rRows*cCols*nColorChannels
    img = skyio.imread(jpg_3)
    # Print some stats
    print("cgsReadImage: \n\tBucket=%s \n\tFile=%s \n\tArraySize=%d %s Type=%s\n" % (bucket, file, img.size, img.shape, img.dtype))
    return(img)

# %%
# Read image from COS
jpg_3 = cgsReadImage(cgsClient_3, cgsBucket_3, cgsImage_3)
# Out:
# <class 'ibm_botocore.response.StreamingBody'>
# cgsReadImage:
# 	Bucket=dataanalystoc-donotdelete-pr-we7lomv4sldueb
# 	File=1.png
# 	ArraySize=1306368 (504, 648, 4) Type=uint8

# %%
cgsDefPlotSize_3=[12,12]
mpl.rcParams['figure.figsize'] = cgsDefPlotSize_3

# %%
# plot image
plt.imshow(jpg_3)
plt.show()

# %% [markdown]
# ## Graphique présentant l'évolution de la variabilité du temps passé par les visiteurs sur le site web (pour les sessions ayant abouti à un achat)

# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.

# %%
# Extract slots from credentials
# Bucket
cgsBucket_4 = cgsCreds_4['BUCKET']
# Filename
cgsImage_4 = cgsCreds_4['FILE']
# Verify current values
print(cgsBucket_4, cgsImage_4)
# Out:
# dataanalystoc-donotdelete-pr-we7lomv4sldueb 15.png

# %%
# Method to read image from cos into numpy.ndarray
def cgsReadImage(client, bucket, file):
    # Download file from COS into a 'ibm_botocore.response.StreamingBody' object
    isr_4 = client.get_object(Bucket=bucket, Key=file)
    # Extract the jpeg image data from the 'Body' slot into a byte array
    jpg_4 = isr_4['Body']
    print(type(jpg_4))
    # needed by skyio.imread
    if not hasattr(jpg_4, "__iter__"): jpg_4.__iter__ = types.MethodType( __iter__, jpg_4)
    # Convert the jpeg image data into a numpy.ndarray of size rRows*cCols*nColorChannels
    img = skyio.imread(jpg_4)
    # Print some stats
    print("cgsReadImage: \n\tBucket=%s \n\tFile=%s \n\tArraySize=%d %s Type=%s\n" % (bucket, file, img.size, img.shape, img.dtype))
    return(img)

# %%
# Read image from COS
jpg_4 = cgsReadImage(cgsClient_4, cgsBucket_4, cgsImage_4)
# Out:
# <class 'ibm_botocore.response.StreamingBody'>
# cgsReadImage:
# 	Bucket=dataanalystoc-donotdelete-pr-we7lomv4sldueb
# 	File=15.png
# 	ArraySize=1306368 (504, 648, 4) Type=uint8

# %%
cgsDefPlotSize_4=[12,12]
mpl.rcParams['figure.figsize'] = cgsDefPlotSize_4

# %%
# plot image
plt.imshow(jpg_4)
plt.show()

# %% [markdown]
# ## Pensez-vous que le chiffre d'affaires ré-augmentera le mois prochain ? Justifiez votre réponse uniquement à l'aide d'un des 5 graphiques choisis.

# %% [markdown]
# #### Tant que les ventes de produits high-tech ne recommencent pas, le chiffre d'affaires ne va pas remonter, car ces sont les produits high-tech qui représentent le pourcentage plus haut revenu.
# ####  On peut voir cela dans le graphique suivant.

# %%
# plot image
plt.imshow(jpg_5)
plt.show()

# %% [markdown]
# ## Mission n°3
#
# C’est l’heure, vous devez présenter et commenter vos différentes slides au reste de l’entreprise. C’est votre mentor qui jouera ce rôle et vous posera des questions, si besoin.

# %% [markdown]
# ## Mission n°4
#
# Après la présentation auprès de votre mentor, profitez-en pour vous renseigner sur son profil, car c’est un professionnel en poste, comme vous dans ce projet.
#
# Vous pourriez, par exemple, lui poser les questions suivantes (ou d’autres !) :
#
# 1. As-tu déjà vécu certaines des situations de ce projet ? Et toi, quelle est ta journée-type ?
# 2. Quel est ton rôle au sein de ton organisation ? En quoi ton travail est-il important pour l'entreprise ?
# 3. De quelles compétences as-tu le plus besoin : statistiques, programmation, bases de données, SQL, etc. ? Quels langages et outils utilises-tu le plus souvent ?
# 4. Quelle importance accordes-tu à la connaissance du domaine dans lequel tu travailles (du “métier” de ton entreprise) dans l’analyse des données ?
# 5. A ton avis, comment peut-on améliorer notre société avec la data ? Crois-tu qu'il en existe un aspect "social" ?
